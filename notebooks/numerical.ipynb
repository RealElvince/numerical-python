# %%
import numpy as np
import math

# %% [markdown]
# ### Basic Arithmetic

# %%
scalar_a = 15
scalar_b = 4

# %%
print("\n --- Basic Arithmetic Operation---")
print(f"Adddition: {scalar_a} + {scalar_b} = {scalar_a + scalar_b}")
# Out:
#  --- Basic Arithmetic Operation---
# Adddition: 15 + 4 = 19
